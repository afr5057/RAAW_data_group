# %%
import fix_yahoo_finance as yf
import pandas as pd
import requests
import pymongo
import datetime

# %%
# Extracted from https://www.nasdaq.com/screening/company-list.aspx
file_path = "Resources/companylist.csv"
df = pd.read_csv(file_path)
df = df[["Symbol","Name","LastSale","MarketCap","IPOyear","Sector","industry","Summary Quote"]]

# Create Dataframe for Technology
df = df.loc[df["Sector"]=="Technology"]
df = df.iloc[0:50,:]
start_date = "2004-05-03"
end_date = "2019-05-03"

# Review Data
df.head()
# Out:
#    Symbol                    Name  LastSale MarketCap  IPOyear      Sector  \
# 0     DDD  3D Systems Corporation     11.15     $1.3B      NaN  Technology
# 3    WUBA             58.com Inc.     72.45   $10.74B   2013.0  Technology
# 4    EGHT                 8x8 Inc     24.21    $2.32B      NaN  Technology
# 7    ATEN      A10 Networks, Inc.      6.49  $487.94M   2014.0  Technology
# 10    AAN      Aaron&#39;s,  Inc.     58.75    $3.98B      NaN  Technology
#
#                                            industry  \
# 0           Computer Software: Prepackaged Software
# 3   Computer Software: Programming, Data Processing
# 4                                      EDP Services
# 7                 Computer Communications Equipment
# 10                  Diversified Commercial Services
#
#                          Summary Quote
# 0    https://www.nasdaq.com/symbol/ddd
# 3   https://www.nasdaq.com/symbol/wuba
# 4   https://www.nasdaq.com/symbol/eght
# 7   https://www.nasdaq.com/symbol/aten
# 10   https://www.nasdaq.com/symbol/aan

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.EcoParameters_db

db.StockPrice_Tech.drop()

collection = db.StockPrice_Tech

# %%
# List of tickers to download
tickers = list(df["Symbol"])

# Loop to get data
for ticker in tickers:

    data = yf.download(ticker, start=start_date, end=end_date)
    
    
    try:
        data = data.resample('QS').mean()
        data.reset_index(inplace=True)
        data["Ticker"] = ticker
        data = data[["Ticker","Date","Close","Volume"]]
        list_dict_prices_stock = []
        for item, row in data.iterrows():
            dict_row ={
                "Ticker" : row["Ticker"],
                "Date" : row["Date"].strftime('%Y-%m-%d'),
                "Close" : row["Close"],
                "Volume" : row["Volume"]
                }
            list_dict_prices_stock.append(dict_row)
        db.StockPrice_Tech.insert_many(list_dict_prices_stock)
    except Exception as e:
        print(e)
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded

# %%
list_price = list(db.StockPrice_Tech.find({"Ticker":"WUBA"}))
print(list_price)
# Out:
# [{'_id': ObjectId('5ccdd4f7144148193844fe9b'), 'Ticker': 'WUBA', 'Date': '2013-10-01', 'Close': 31.716904761904765, 'Volume': 1285471.4285714286}, {'_id': ObjectId('5ccdd4f7144148193844fe9c'), 'Ticker': 'WUBA', 'Date': '2014-01-01', 'Close': 42.1855737704918, 'Volume': 1054572.1311475409}, {'_id': ObjectId('5ccdd4f7144148193844fe9d'), 'Ticker': 'WUBA', 'Date': '2014-04-01', 'Close': 42.43650793650793, 'Volume': 1387584.126984127}, {'_id': ObjectId('5ccdd4f7144148193844fe9e'), 'Ticker': 'WUBA', 'Date': '2014-07-01', 'Close': 46.273906249999996, 'Volume': 1521800.0}, {'_id': ObjectId('5ccdd4f7144148193844fe9f'), 'Ticker': 'WUBA', 'Date': '2014-10-01', 'Close': 41.26015625, 'Volume': 837734.375}, {'_id': ObjectId('5ccdd4f7144148193844fea0'), 'Ticker': 'WUBA', 'Date': '2015-01-01', 'Close': 42.30557377049182, 'Volume': 685167.2131147541}, {'_id': ObjectId('5ccdd4f7144148193844fea1'), 'Ticker': 'WUBA', 'Date': '2015-04-01', 'Close': 72.64174603174607, 'Volume': 1638768.253968254}, {'_id': ObjectId('5ccdd4f7144148193844fea2'), 'Ticker': 'WUBA', 'Date': '2015-07-01', 'Close': 51.87109375, 'Volume': 1290050.0}, {'_id': ObjectId('5ccdd4f7144148193844fea3'), 'Ticker': 'WUBA', 'Date': '2015-10-01', 'Close': 56.327656249999976, 'Volume': 1187609.375}, {'_id': ObjectId('5ccdd4f7144148193844fea4'), 'Ticker': 'WUBA', 'Date': '2016-01-01', 'Close': 55.24295081967214, 'Volume': 911059.0163934426}, {'_id': ObjectId('5ccdd4f7144148193844fea5'), 'Ticker': 'WUBA', 'Date': '2016-04-01', 'Close': 51.57593750000001, 'Volume': 1374839.0625}, {'_id': ObjectId('5ccdd4f7144148193844fea6'), 'Ticker': 'WUBA', 'Date': '2016-07-01', 'Close': 48.8565625, 'Volume': 1635032.8125}, {'_id': ObjectId('5ccdd4f7144148193844fea7'), 'Ticker': 'WUBA', 'Date': '2016-10-01', 'Close': 37.13936507936508, 'Volume': 1393725.396825397}, {'_id': ObjectId('5ccdd4f7144148193844fea8'), 'Ticker': 'WUBA', 'Date': '2017-01-01', 'Close': 33.02145161290323, 'Volume': 1335206.4516129033}, {'_id': ObjectId('5ccdd4f7144148193844fea9'), 'Ticker': 'WUBA', 'Date': '2017-04-01', 'Close': 41.19476190476191, 'Volume': 1187195.238095238}, {'_id': ObjectId('5ccdd4f7144148193844feaa'), 'Ticker': 'WUBA', 'Date': '2017-07-01', 'Close': 56.834603174603195, 'Volume': 1569961.9047619049}, {'_id': ObjectId('5ccdd4f7144148193844feab'), 'Ticker': 'WUBA', 'Date': '2017-10-01', 'Close': 69.26126984126984, 'Volume': 1015220.6349206349}, {'_id': ObjectId('5ccdd4f7144148193844feac'), 'Ticker': 'WUBA', 'Date': '2018-01-01', 'Close': 78.92098360655737, 'Volume': 1161822.950819672}, {'_id': ObjectId('5ccdd4f7144148193844fead'), 'Ticker': 'WUBA', 'Date': '2018-04-01', 'Close': 81.52875000000002, 'Volume': 1023406.25}, {'_id': ObjectId('5ccdd4f7144148193844feae'), 'Ticker': 'WUBA', 'Date': '2018-07-01', 'Close': 69.13968253968254, 'Volume': 1209266.6666666667}, {'_id': ObjectId('5ccdd4f7144148193844feaf'), 'Ticker': 'WUBA', 'Date': '2018-10-01', 'Close': 60.985079365079386, 'Volume': 1112426.9841269841}, {'_id': ObjectId('5ccdd4f7144148193844feb0'), 'Ticker': 'WUBA', 'Date': '2019-01-01', 'Close': 62.99901639344262, 'Volume': 874072.131147541}, {'_id': ObjectId('5ccdd4f7144148193844feb1'), 'Ticker': 'WUBA', 'Date': '2019-04-01', 'Close': 70.69166666666668, 'Volume': 738970.8333333334}]

# %%
list_price = list(db.StockPrice_Tech.find())
print(list_price)
# Out:
# [{'_id': ObjectId('5ccdd4f7144148193844fe5e'), 'Ticker': 'DDD', 'Date': '2004-04-01', 'Close': 3.813414634146342, 'Volume': 33739.0243902439}, {'_id': ObjectId('5ccdd4f7144148193844fe5f'), 'Ticker': 'DDD', 'Date': '2004-07-01', 'Close': 3.80390625, 'Volume': 33145.3125}, {'_id': ObjectId('5ccdd4f7144148193844fe60'), 'Ticker': 'DDD', 'Date': '2004-10-01', 'Close': 4.934374999999999, 'Volume': 90787.5}, {'_id': ObjectId('5ccdd4f7144148193844fe61'), 'Ticker': 'DDD', 'Date': '2005-01-01', 'Close': 6.858524590163933, 'Volume': 182291.80327868852}, {'_id': ObjectId('5ccdd4f7144148193844fe62'), 'Ticker': 'DDD', 'Date': '2005-04-01', 'Close': 6.88640625, 'Volume': 226753.125}, {'_id': ObjectId('5ccdd4f7144148193844fe63'), 'Ticker': 'DDD', 'Date': '2005-07-01', 'Close': 7.478749999999998, 'Volume': 215620.3125}, {'_id': ObjectId('5ccdd4f7144148193844fe64'), 'Ticker': 'DDD', 'Date': '2005-10-01', 'Close': 6.2188888888888885, 'Volume': 177500.0}, {'_id': ObjectId('5ccdd4f7144148193844fe65'), 'Ticker': 'DDD', 'Date': '2006-01-01', 'Close': 6.669999999999998, 'Volume': 198188.70967741936}, {'_id': ObjectId('5ccdd4f7144148193844fe66'), 'Ticker': 'DDD', 'Date': '2006-04-01', 'Close': 6.978412698412698, 'Volume': 178214.2857142857}, {'_id': ObjectId('5ccdd4f7144148193844fe67'), 'Ticker': 'DDD', 'Date': '2006-07-01', 'Close': 5.5844444444444425, 'Volume': 264514.28571428574}, {'_id': ObjectId('5ccdd4f7144148193844fe68'), 'Ticker': 'DDD', 'Date': '2006-10-01', 'Close': 5.268095238095238, 'Volume': 249204.7619047619}, {'_id': ObjectId('5ccdd4f7144148193844fe69'), 'Ticker': 'DDD', 'Date': '2007-01-01', 'Close': 5.9626229508196715, 'Volume': 248036.0655737705}, {'_id': ObjectId('5ccdd4f7144148193844fe6a'), 'Ticker': 'DDD', 'Date': '2007-04-01', 'Close': 7.048730158730158, 'Volume': 286709.5238095238}, {'_id': ObjectId('5ccdd4f7144148193844fe6b'), 'Ticker': 'DDD', 'Date': '2007-07-01', 'Close': 7.406666666666668, 'Volume': 341709.5238095238}, {'_id': ObjectId('5ccdd4f7144148193844fe6c'), 'Ticker': 'DDD', 'Date': '2007-10-01', 'Close': 6.445781250000001, 'Volume': 250640.625}, {'_id': ObjectId('5ccdd4f7144148193844fe6d'), 'Ticker': 'DDD', 'Date': '2008-01-01', 'Close': 4.761147540983605, 'Volume': 351068.8524590164}, {'_id': ObjectId('5ccdd4f7144148193844fe6e'), 'Ticker': 'DDD', 'Date': '2008-04-01', 'Close': 3.97859375, 'Volume': 294660.9375}, {'_id': ObjectId('5ccdd4f7144148193844fe6f'), 'Ticker': 'DDD', 'Date': '2008-07-01', 'Close': 3.849531249999999, 'Volume': 186468.75}, {'_id': ObjectId('5ccdd4f7144148193844fe70'), 'Ticker': 'DDD', 'Date': '2008-10-01', 'Close': 2.864687500000001, 'Volume': 182798.4375}, {'_id': ObjectId('5ccdd4f7144148193844fe71'), 'Ticker': 'DDD', 'Date': '2009-01-01', 'Close': 2.128524590163934, 'Volume': 112529.5081967213}, {'_id': ObjectId('5ccdd4f7144148193844fe72'), 'Ticker': 'DDD', 'Date': '2009-04-01', 'Close': 2.293968253968253, 'Volume': 136509.52380952382}, {'_id': ObjectId('5ccdd4f7144148193844fe73'), 'Ticker': 'DDD', 'Date': '2009-07-01', 'Close': 2.6823437500000007, 'Volume': 108342.1875}, {'_id': ObjectId('5ccdd4f7144148193844fe74'), 'Ticker': 'DDD', 'Date': '2009-10-01', 'Close': 3.4221874999999997, 'Volume': 123192.1875}, {'_id': ObjectId('5ccdd4f7144148193844fe75'), 'Ticker': 'DDD', 'Date': '2010-01-01', 'Close': 4.368196721311475, 'Volume': 153555.73770491802}, {'_id': ObjectId('5ccdd4f7144148193844fe76'), 'Ticker': 'DDD', 'Date': '2010-04-01', 'Close': 4.642857142857142, 'Volume': 146176.19047619047}, {'_id': ObjectId('5ccdd4f7144148193844fe77'), 'Ticker': 'DDD', 'Date': '2010-07-01', 'Close': 4.575156250000001, 'Volume': 135206.25}, {'_id': ObjectId('5ccdd4f7144148193844fe78'), 'Ticker': 'DDD', 'Date': '2010-10-01', 'Close': 8.55765625, 'Volume': 338240.625}, {'_id': ObjectId('5ccdd4f7144148193844fe79'), 'Ticker': 'DDD', 'Date': '2011-01-01', 'Close': 12.784354838709678, 'Volume': 607920.9677419355}, {'_id': ObjectId('5ccdd4f7144148193844fe7a'), 'Ticker': 'DDD', 'Date': '2011-04-01', 'Close': 13.87888888 ...
